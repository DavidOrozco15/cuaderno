# %%
# Crear una lista inicial
mi_lista = [3, 1, 4, 1, 5, 9]

# append(): Agrega un elemento al final de la lista
mi_lista.append(2)
# Resultado: [3, 1, 4, 1, 5, 9, 2]

# extend(): Agrega múltiples elementos al final de la lista
mi_lista.extend([6, 5])
# Resultado: [3, 1, 4, 1, 5, 9, 2, 6, 5]

# insert(): Inserta un elemento en una posición específica
mi_lista.insert(2, 10)  # Inserta 10 en el índice 2
# Resultado: [3, 1, 10, 4, 1, 5, 9, 2, 6, 5]

# remove(): Elimina la primera aparición de un elemento
mi_lista.remove(1)
# Resultado: [3, 10, 4, 1, 5, 9, 2, 6, 5] (el primer '1' fue eliminado)

# pop(): Elimina y devuelve el último elemento (o uno en un índice específico)
ultimo = mi_lista.pop()  # Elimina el último
# Resultado de mi_lista: [3, 10, 4, 1, 5, 9, 2, 6]
# Resultado de ultimo: 5

# index(): Devuelve el índice de la primera aparición del valor
indice = mi_lista.index(9)
# Resultado: 5

# count(): Cuenta cuántas veces aparece un elemento
veces = mi_lista.count(1)
# Resultado: 1

# sort(): Ordena la lista en orden ascendente (modifica la lista original)
mi_lista.sort()
# Resultado: [1, 2, 3, 4, 6, 9, 10]

# sorted(): Devuelve una nueva lista ordenada (sin modificar la original)
lista_ordenada = sorted([4, 2, 5, 1])
# Resultado: [1, 2, 4, 5]

# reverse(): Invierte el orden de los elementos en la lista
mi_lista.reverse()
# Resultado: [10, 9, 6, 4, 3, 2, 1]

# copy(): Crea una copia superficial de la lista
copia_lista = mi_lista.copy()
# Resultado: copia_lista = [10, 9, 6, 4, 3, 2, 1]

# clear(): Elimina todos los elementos de la lista
mi_lista.clear()
# Resultado: []

# %%
import os
pendientes = []
os.system("clear")
isActive = True
while isActive:
    os.system("clear")
    print("Bienvenido a Lista de Pendientes")
    print("1. Consultar tareas")
    print("2. Añadir Tareas")
    print("3. Actualizar Tarea")
    print("4. Completar tarea")
    print("0. Salir")
    opcion = int(input("Ingresa la Opcion: "))
    match opcion:
        case 1:
            os.system("clear")
            if len(pendientes)==0:
                print("No tiene tareas pendientes")
            else:
                print("Sus tareas pendientes son: ")
                print(pendientes)
        case 2:
            os.system("clear")
            print("Agregar Tareas")
            pendientes.append(input("Ingrese la nueva tarea: "))
            print(f"Ahora sus tareas pendientes son: {pendientes}")
        case 3:
            pass
        case 4:
            os.system("clear")
            print("Completar Tareas")
            print("Sus tareas pendientes son:")
            for indice, tarea in enumerate(pendientes):
                print(f"[{indice}] {tarea}")
            completado = pendientes.pop(int(input("Ingrese el numero de la tarea que desea completar")))
            print(f"La tarea {completado} fue completada con exito")
            print(f"La lista actualizada es: {pendientes}")
        case 0:
            print("Gracias por usar el programa.")
            isActive = False
        case _:
            pass
# Out:
# Bienvenido a Lista de Pendientes
# 1. Consultar tareas
# 2. Añadir Tareas
# 3. Actualizar Tarea
# 4. Completar tarea
# 0. Salir
# Agregar Tareas
# Ahora sus tareas pendientes son: ['ola']
# Bienvenido a Lista de Pendientes
# 1. Consultar tareas
# 2. Añadir Tareas
# 3. Actualizar Tarea
# 4. Completar tarea
# 0. Salir
# Sus tareas pendientes son:
# ['ola']
# Bienvenido a Lista de Pendientes
# 1. Consultar tareas
# 2. Añadir Tareas
# 3. Actualizar Tarea
# 4. Completar tarea
# 0. Salir
# Sus tareas pendientes son:
# ['ola']
# Bienvenido a Lista de Pendientes
# 1. Consultar tareas
# 2. Añadir Tareas
# 3. Actualizar Tarea
# 4. Completar tarea
# 0. Salir
# Sus tareas pendientes son:
# ['ola']
# Bienvenido a Lista de Pendientes
# 1. Consultar tareas
# 2. Añadir Tareas
# 3. Actualizar Tarea
# 4. Completar tarea
# 0. Salir
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
